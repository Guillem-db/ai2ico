# %% [markdown]
# # ICO Data

# %% [markdown]
# ## Load raw data

# %%
import pandas as pd
tokendata = pd.read_csv("data/tokendata.csv").drop("Unnamed: 0", axis=1)
tokendata.loc[:, "name"] = tokendata["name"].map(str.lower) 
icotracker = pd.read_csv("data/icotracker.csv").drop("Unnamed: 0", axis=1)
icotracker.loc[:, "name"] = icotracker["name"].map(str.lower)
icostats = pd.read_csv("data/icostats.csv").drop("Unnamed: 0", axis=1)
icostats.loc[:, "name"] = icostats["name"].map(str.lower)
coinmcap = pd.read_csv("data/coinmarketcap_historical.csv").drop("Unnamed: 0", axis=1)
whitepapers = pd.read_csv("data/whitepapers_raw.csv").drop("Unnamed: 0", axis=1)
whitepapers.loc[:, "name"] = whitepapers["name"].map(str.lower)

# %%
valid_tokendata = tokendata[["name", "symbol", "sale_price", "curr_price"]].dropna().copy()

# %%
valid_tokendata.head() # BUG: names and tickers do not match. Gotta review the code
# Out:
#          name symbol  sale_price  curr_price
# 102     propy    PRO       1.093       2.388
# 103  maecenas    ART       0.519       1.246
# 104      qtum   QTUM       0.307      38.397
# 105     waves  WAVES       0.188       8.779
# 106   ethlend   LEND       0.016       0.204

# %%
#df = pd.merge(whitepapers, valid_tokendata, left_on="name", right_on="name", how="left")
#df.dropna().head()

# %%
df = pd.merge(whitepapers, icostats[["name", "ico_price"]], left_on="name", right_on="name", how="left")
df.dropna()
# Out:
#                                                   text symbol          name  \
# 104  b'OmiseGO\n\nDecentralized Exchange and Paymen...    OMG       omisego
# 105  b"V0.5\n\nThe\xc2\xa0CoinDash\xc2\xa0Team\n\nC...    CDT      coindash
# 108  b'\x0c\xc2\xa0\n\n\xc2\xa0\n1.0\xc2\xa0Abstrac...    WGR        wagerr
# 188  b'1\n\n\x0cContents\n\n2\n\n\x0c33\n\n\x0c44\n...    CVC         civic
# 365  b" \n\n \n\nWHITEPAPER \n\nWe believe empoweri...   POWR  power ledger
# 510  b' \n\n \n\n \n\n \n\nTierion Network \n\nA\xc...    TNT       tierion
# 551  b'<HTML>\n<HEAD>\n<TITLE>Not Found</TITLE>\n</...    SNT     santiment
#
#      ico_price
# 104   0.000124
# 105   0.000014
# 108   0.000026
# 188   0.000039
# 365   0.000077
# 510   0.000017
# 551   0.000104

# %%
# Coinmcap has the ticker included in the name,
# remove it to match the name column from other DataFrames
coinmcap.loc[:, "name"] = coinmcap["name"].map(lambda x: x.lower().split(" ")[-1])

# %% [markdown]
# ## Approximate returns

# %%
# Approximate returns for each ICO
# Get the first and last date from historical price data for each ico.
first_price = coinmcap.groupby("name").apply(lambda x: x.sort_values("date", ascending=False).iloc[-1])[["price"]]
first_price.columns = ["ico_price_aprox"]
last_price = coinmcap.groupby("name").apply(lambda x: x.sort_values("date", ascending=True).iloc[-1])[["price"]]
max_price = coinmcap.groupby("name")[["price"]].max()
first_price.columns = ["max_price"]
market_cap = coinmcap.groupby("name").apply(lambda x: x.sort_values("date", ascending=True).iloc[-1])[["market_cap"]]

# %%
merge1 = pd.merge(whitepapers, max_price, left_on="name", right_index=True, how="left")
merge2 = pd.merge(merge1, market_cap, left_on="name", right_index=True, how="left")
merge3 = pd.merge(merge2, first_price, left_on="name", right_index=True, how="left")

# %%
merge3.dropna()
# Out:
#                                                   text  symbol         name  \
# 18   b'A DECENTRALIZED ESPORTS BETTING SYSTEM\n\nGi...     GIM        gimli
# 75   b' \n \n \n\nWhite Paper  \n\n(Some details mi...      CS      credits
# 96   b'Opus - Decentralized music distribution usin...     OPT         opus
# 104  b'OmiseGO\n\nDecentralized Exchange and Paymen...     OMG      omisego
# 105  b"V0.5\n\nThe\xc2\xa0CoinDash\xc2\xa0Team\n\nC...     CDT     coindash
# 108  b'\x0c\xc2\xa0\n\n\xc2\xa0\n1.0\xc2\xa0Abstrac...     WGR       wagerr
# 111  b' \n\nDECENTRALIZED BLOCKCHAIN LODGING ECOSYS...     EPY        emphy
# 121  b"\x0c \n\nFirst\xe2\x80\x8b \xe2\x80\x8bInter...    PRIX     privatix
# 124  b' \n \n \n\nInternxt  \n\nWelcome To A New In...    INXT     internxt
# 125  b'+\n\nWhite Paper\n\nJuly 2017\n\nSocial is a...  SOCIAL        nexus
# 134  b'WHITE PAPER \n\nSnovio \xe2\x80\x93 The Worl...    SNOV       snovio
# 138  b'SOCIAL PUBLIC OPINION POLLS \nON THE BLOCKCH...    POLL    clearpoll
# 158  b"WHITEPAPER\n\nThe Community-Powered Search E...     PST    presearch
# 160  b'\x0c\xc2\xa0\n\nTable\xe2\x80\x8b \xe2\x80\x...     ERO     eroscoin
# 184  b'WaBi (\xe8\x9b\x99\xe5\xb8\x81) - crypto tok...    WaBi         wabi
# 188  b'1\n\n\x0cContents\n\n2\n\n\x0c33\n\n\x0c44\n...     CVC        civic
# 192  b'\x0cFujinto Whitepaper \n\nhttp://fujinto.io...     NTO      fujinto
# 199  b' \n\nBounty0x.io \n\n\xe2\x80\x98Rewarding t...    BNTY     bounty0x
# 200  b'WHITE PAPER\n\nSmart Investments Into Crypto...    DACF   cryptofund
# 208  b'PAYMENT PLATFORM \n\nWHITEPAPER \n\nFinal Ve...    TenX         tenx
# 222  b'BLOCKCHAIN PLATFORM FOR TICKET SYSTEMS\n\nAN...     TKT       crypto
# 224  b"DECENTRALIZED SPORTS\nINVESTMENT & FUNDING \...     SPF     sportyfi
# 227  b"\xc2\xa0\n\nCo\xe2\x80\x8bE\xe2\x80\x8bx\xe2...   COXST  coexistcoin
# 238  b'1\n\n\x0cEthbet Whitepaper\n\nVersion 3.0\n\...    EBET       ethbet
# 247  b'2017\n\nVersion 2.1.0\n\n\x0cDigital inherit...    DGPT    digipulse
# 252  b' \n\n \n\n \n\n \n\nADSHARES \n\nWHITEPAPER ...    ADST     adshares
# 270  b'Hybrid Intelligence for\n\nE\x1bective Asset...     CND   cindicator
# 292  b' \n\n \n \n\n \n\n \n\n \n\n \n\n \n\nWHITE ...     UCN      unicoin
# 306  b'REVOLUTIONIZING ALL \nTHINGS CANNABIS WITH \...     PRG      paragon
# 309  b'\x001\n\n\x0cIndex of contents\n\nAbstract\x...    REAL         real
# 318  b' Overview & White Paper\n\n\x0cThe purpose o...     ETN  electroneum
# 323  b'\x0c2\n\nAdvance warning\n\nThe Initial Coin...     DRT    domraider
# 324  b' \n\n \nCyberMiles:  Empowering the Decentra...     CMT   cybermiles
# 342  b'The Ethereum-powered Reputation Platform for...    CRED       verify
# 370  b'\x0c\x0c\x0c\x0c\x0c\x0c\x0c\x0c\x0c\x0c\x0c...       R       revain
# 389  b'T H E   P U B L I C A\n\nW H I T E   PA P E ...     PBL      publica
# 414  b" \n \n\n \n\n \n\nTable of contents \n \n\n ...     LAT      latoken
# 429  b'+\n\nWhite Paper\n\nJuly 2017\n\nSocial is a...     SCL       social
# 455  b"\xc2\xa0\n\n\xc2\xa0\n\n\xc2\xa0\n\n\xc2\xa0...     BRD        bread
# 457  b" \n\n\xc2\xa0\n\n\xc2\xa0\n\nWhitepaper\xc2\...     CYR       cypher
# 465  b"COSS: CRYPTO-ONE-STOP-SOLUTION MADE EASYinfo...    COSS         coss
# 467  b"ICO SaaS Solution\n\nNothing provided herein...    ICOS         icos
# 469  b' \n\n \n\n \n\n \n\n \n\n \n\n \n\n \n\n \n\...    DRGN  dragonchain
# 474  b'Enigma Catalyst: A machine-based investing p...    ECAT       enigma
# 476  b'(cid:1)\n\nWHITEPAPER\n\n(cid:55)(cid:38)(ci...     MED     medibloc
# 510  b' \n\n \n\n \n\n \n\nTierion Network \n\nA\xc...     TNT      tierion
# 518  b" \n\n \n\n \n\n \n\n \n\n \n\nXPlay \xe2\x80...     XPA        xplay
# 540  b"Blockchain for Airline Passengers Safety\n\n...     ARN        aeron
# 541  b'Lowering Financial Inclusion Barriers With a...     EVX       everex
# 547  b"P2P \nCRYPTOCURRENCY \nEXCHANGE\n\nSell and ...     QVT       qvolta
# 567  b'Node\n\nWelcome to \nWireless Future\nIntell...    NODE         node
#
#          price    market_cap  max_price
# 18    0.070379  5.630287e+06   0.020800
# 75    1.100000  3.420000e+03   0.000109
# 96    0.084597  1.185042e+07   0.047187
# 104  20.290001  2.070642e+09   0.439359
# 105   0.258687  1.450328e+08   0.171627
# 108   0.657847  1.203860e+08   0.092859
# 111   0.359808  2.747819e+06   0.218479
# 121  14.400000  1.702713e+07   1.840000
# 124  26.820000  1.688424e+07   2.890000
# 125  12.220000  6.704486e+08   0.001628
# 134   0.197744  8.008668e+07   0.004767
# 138   6.280000  4.396500e+07   0.454542
# 158   0.704324  1.091701e+08   0.182448
# 160   0.164924  1.226685e+07   0.140089
# 184   3.470000  1.569688e+08   2.150000
# 188   1.210000  4.145107e+08   0.186979
# 192   0.465367  1.069233e+06   0.465367
# 199   0.554616  6.477744e+07   0.169402
# 200   1.280000  6.325700e+05   0.089439
# 208  34.029999  3.994171e+08  34.029999
# 222   1.510000  1.963640e+05   0.004565
# 224   0.513502  2.545584e+07   0.161755
# 227   0.089625  1.749860e+05   0.001187
# 238   0.252719  2.148739e+06   0.240243
# 247   3.880000  5.437184e+06   1.340000
# 252   0.651406  9.790742e+06   0.225833
# 270   0.174528  2.523640e+08   0.023640
# 292   0.310727  9.250940e+05   0.000093
# 306   0.722157  4.689442e+07   0.396278
# 309   1.310000  1.315001e+07   0.521565
# 318   0.183784  9.184640e+08   0.033554
# 323   0.097008  5.738029e+07   0.049529
# 324   0.500985  2.170016e+08   0.228648
# 342   2.180000  2.605590e+07   0.359365
# 370   1.400000  2.576697e+08   0.090754
# 389   2.140000  3.967976e+07   0.137106
# 414   1.480000  1.151631e+08   0.181674
# 429   0.961214  1.606575e+07   0.245394
# 455   3.150000  1.884288e+08   1.550000
# 457   0.067099  4.271060e+05   0.005361
# 465   1.190000  7.411589e+07   0.069246
# 467  50.889999  2.398498e+07  50.889999
# 469   4.560000  1.086612e+09   0.407793
# 474   5.900000  1.212100e+04   0.007539
# 476   0.083872  2.487977e+08   0.025737
# 510   0.355352  1.522616e+08   0.173644
# 518   0.184858  1.848583e+08   0.014243
# 540   5.370000  6.985268e+07   0.294639
# 541   5.520000  9.108667e+07   1.430000
# 547   2.310000  1.555763e+07   0.156140
# 567   0.000558  1.246600e+04   0.000492

# %%
aprox_returns = last_price / first_price

# %% [markdown]
# ## Create pdf_paths

# %%
import os
import numpy as np
    
def get_paths():
    base_path = "data/all_wp/"
    subs = ["upcoming", "past", "current"]
    files = []
    for d in subs:
        files += [os.path.join(base_path, d, f) for f in os.listdir(os.path.join(base_path, d))]
    return files

# %%
def add_whitepaper_path(df):
    pdf_paths = get_paths()
    df["wp_path"] = np.nan
    for path in pdf_paths:
        ticker, name = path.split("/")[-1].split(".")[0].split("_")
        cond_1 = df["name"].values == name.lower()
        cond_2 = df["symbol"].values == ticker
        df.loc[cond_1 & cond_2, "wp_path"] = path
    return df

# %%
data = add_whitepaper_path(merge3)

# %%
#save data
data_final = pd.merge(data, icotracker[["name", "scam"]], left_on="name", right_on="name", how="left")
data_final.to_csv("ICO_data.csv")
